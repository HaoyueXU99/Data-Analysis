# %% [markdown]
# ![image.png](attachment:image.png)

# %%
letter = ['a',"B",'c','D','e','F']
upper_letter = filter(lambda x:x==x.upper(), letter)
print(upper_letter)
print(list(upper_letter))
# Out:
# ...
# ['B', 'D', 'F']

# %%
student_name = ["李元芳","李建国","白静","莫怀宇"]
r = filter(lambda x:x.startswith("李"),student_name)
print(list(r))
# Out:
# ['李元芳', '李建国']
