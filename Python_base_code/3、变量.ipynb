# %%
i = 1

# %%
print(i)
# Out:
# 1

# %%
# 等号是赋值运算符
i = 2
print(i)
# Out:
# 2

# %%
print(i)
# Out:
# 2

# %%
j = 2
print(j)
# Out:
# 2

# %%
# 这个是单行注释 
# 下面我们用的是多行注释
"""
Python拥有多种数据类型
数字 ： 整数(1\2\3) int 和浮点数(1.23\3.54)  float
字符串：是使用一对儿单引号或者是双引号包裹起来的字符
列表
元组
字典
布尔类型
"""
# Out:
# '\nPython拥有多种数据类型\n数字 ： 整数(1\x02\x03)和浮点数(1.23\x03.54)\n字符串：是使用一对儿单引号或者是双引号包裹起来的字符\n'

# %%
# 这就是字符串
name = '大周老师'
print(name)
# Out:
# 大周老师

# %%
# name代表名字
name = "大周老师"
print(name)
# Out:
# 大周老师

# %%
# 布尔类型演示
a = True  # 让某一个变量值为真

# %%
b = False

# %%
print(a)
# Out:
# True

# %%
# 数据类型转换
# 布尔类型转换成整数类型
print(int(True))
# Out:
# 1

# %%
print(int(False))
# Out:
# 0

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(1))
# Out:
# True

# %%
age = 18

# %% [markdown]
# ![image.png](attachment:image.png)
